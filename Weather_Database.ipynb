# %%
# Import dependencies
import pandas as pd
import numpy as np
from citipy import citipy
import sys
sys.path.append('..')
from config import weather_api_key
import requests
import time

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
cities = []


# Identify nearest city for each latitude and longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 765

# %%
# base url for OWM calls
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.

    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
        # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | angouleme
# Processing Record 2 of Set 1 | mayo
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | ostersund
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | guye
# Processing Record 9 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 1 | maceio
# Processing Record 11 of Set 1 | chokurdakh
# Processing Record 12 of Set 1 | motygino
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | soyo
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | balkhash
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | los llanos de aridane
# Processing Record 20 of Set 1 | kruisfontein
# Processing Record 21 of Set 1 | beringovskiy
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | saskylakh
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | jonesboro
# Processing Record 31 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 1 | suez
# Processing Record 33 of Set 1 | bitung
# Processing Record 34 of Set 1 | salalah
# Processing Record 35 of Set 1 | kaitangata
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | niquinohomo
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | marsh harbour
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | penzance
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | talawdi
# City not found. Skipping...
# Processing Record 46 of Set 1 | srednekolymsk
# Processing Record 47 of Set 1 | pelym
# Processing Record 48 of Set 1 | strathmore
# Processing Record 49 of Set 1 | vao
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | tasiilaq
# Processing Record 2 of Set 2 | chontalpa
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | lebu
# Processing Record 5 of Set 2 | bluff
# Processing Record 6 of Set 2 | goderich
# Processing Record 7 of Set 2 | hasaki
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | haines junction
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | bambous virieux
# Processing Record 13 of Set 2 | talnakh
# Processing Record 14 of Set 2 | nanortalik
# Processing Record 15 of Set 2 | severo-kurilsk
# Processing Record 16 of Set 2 | berezovka
# Processing Record 17 of Set 2 | khokhlovo
# Processing Record 18 of Set 2 | at-bashi
# Processing Record 19 of Set 2 | castro
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | jurm
# Processing Record 22 of Set 2 | malaya serdoba
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | hobyo
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | vardo
# Processing Record 27 of Set 2 | waingapu
# Processing Record 28 of Set 2 | tabuk
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | bethel
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | port hedland
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | corumba
# Processing Record 36 of Set 2 | hammerfest
# Processing Record 37 of Set 2 | havoysund
# Processing Record 38 of Set 2 | chuy
# Processing Record 39 of Set 2 | mponela
# Processing Record 40 of Set 2 | seoul
# Processing Record 41 of Set 2 | kralendijk
# Processing Record 42 of Set 2 | dayong
# Processing Record 43 of Set 2 | lavrentiya
# Processing Record 44 of Set 2 | charters towers
# Processing Record 45 of Set 2 | messina
# Processing Record 46 of Set 2 | teahupoo
# Processing Record 47 of Set 2 | flin flon
# Processing Record 48 of Set 2 | dillon
# Processing Record 49 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | pasni
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | chapais
# Processing Record 3 of Set 3 | ancud
# Processing Record 4 of Set 3 | lompoc
# Processing Record 5 of Set 3 | yeniseysk
# Processing Record 6 of Set 3 | vila velha
# Processing Record 7 of Set 3 | amarante do maranhao
# Processing Record 8 of Set 3 | doboj
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | cape town
# Processing Record 11 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 3 | tazovskiy
# Processing Record 13 of Set 3 | payson
# Processing Record 14 of Set 3 | hamilton
# Processing Record 15 of Set 3 | vestmannaeyjar
# Processing Record 16 of Set 3 | rundu
# Processing Record 17 of Set 3 | agirish
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | lata
# Processing Record 21 of Set 3 | nikolskoye
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | saint george
# Processing Record 24 of Set 3 | port-gentil
# Processing Record 25 of Set 3 | deputatskiy
# Processing Record 26 of Set 3 | erenhot
# Processing Record 27 of Set 3 | lakes entrance
# Processing Record 28 of Set 3 | kadoma
# Processing Record 29 of Set 3 | loo
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | peniche
# Processing Record 32 of Set 3 | vila franca do campo
# Processing Record 33 of Set 3 | ponta do sol
# Processing Record 34 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 3 | narsaq
# Processing Record 36 of Set 3 | vetluzhskiy
# Processing Record 37 of Set 3 | pokrovsk
# Processing Record 38 of Set 3 | uige
# Processing Record 39 of Set 3 | husavik
# Processing Record 40 of Set 3 | sergeyevka
# Processing Record 41 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | gondanglegi
# Processing Record 44 of Set 3 | quthing
# Processing Record 45 of Set 3 | melendugno
# Processing Record 46 of Set 3 | mushie
# Processing Record 47 of Set 3 | hambantota
# Processing Record 48 of Set 3 | sitka
# Processing Record 49 of Set 3 | chicama
# Processing Record 50 of Set 3 | muscat
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | rangapara
# Processing Record 3 of Set 4 | zinder
# Processing Record 4 of Set 4 | barcelos
# Processing Record 5 of Set 4 | otukpo
# Processing Record 6 of Set 4 | awjilah
# Processing Record 7 of Set 4 | floriano
# Processing Record 8 of Set 4 | saldanha
# Processing Record 9 of Set 4 | khatanga
# Processing Record 10 of Set 4 | harper
# Processing Record 11 of Set 4 | eydhafushi
# Processing Record 12 of Set 4 | sinnamary
# Processing Record 13 of Set 4 | pitkyaranta
# Processing Record 14 of Set 4 | tautira
# Processing Record 15 of Set 4 | mbandaka
# Processing Record 16 of Set 4 | saint-pierre
# Processing Record 17 of Set 4 | totskoye
# Processing Record 18 of Set 4 | praia da vitoria
# Processing Record 19 of Set 4 | sao miguel do araguaia
# Processing Record 20 of Set 4 | pavino
# Processing Record 21 of Set 4 | meulaboh
# Processing Record 22 of Set 4 | plettenberg bay
# Processing Record 23 of Set 4 | airai
# Processing Record 24 of Set 4 | sangar
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | millet
# Processing Record 27 of Set 4 | mpulungu
# Processing Record 28 of Set 4 | alta floresta
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 31 of Set 4 | saint-joseph
# Processing Record 32 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 4 | aksarka
# Processing Record 34 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 4 | coihueco
# Processing Record 36 of Set 4 | djambala
# Processing Record 37 of Set 4 | zafra
# Processing Record 38 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 39 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 4 | madimba
# Processing Record 41 of Set 4 | tilichiki
# Processing Record 42 of Set 4 | krasnoselkup
# Processing Record 43 of Set 4 | grindavik
# Processing Record 44 of Set 4 | sur
# Processing Record 45 of Set 4 | morehead
# Processing Record 46 of Set 4 | acapulco
# Processing Record 47 of Set 4 | guilin
# Processing Record 48 of Set 4 | masallatah
# Processing Record 49 of Set 4 | uddevalla
# Processing Record 50 of Set 4 | sarh
# Processing Record 1 of Set 5 | tigre
# Processing Record 2 of Set 5 | comodoro rivadavia
# Processing Record 3 of Set 5 | ocos
# Processing Record 4 of Set 5 | aswan
# Processing Record 5 of Set 5 | kamaishi
# Processing Record 6 of Set 5 | dingle
# Processing Record 7 of Set 5 | prabumulih
# Processing Record 8 of Set 5 | valmiera
# Processing Record 9 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 5 | lasa
# Processing Record 11 of Set 5 | antofagasta
# Processing Record 12 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 5 | veraval
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | port hardy
# Processing Record 16 of Set 5 | gorele
# Processing Record 17 of Set 5 | hobart
# Processing Record 18 of Set 5 | turukhansk
# Processing Record 19 of Set 5 | bara
# Processing Record 20 of Set 5 | hastings
# Processing Record 21 of Set 5 | akhtanizovskaya
# Processing Record 22 of Set 5 | sharan
# Processing Record 23 of Set 5 | cayenne
# Processing Record 24 of Set 5 | te anau
# Processing Record 25 of Set 5 | pevek
# Processing Record 26 of Set 5 | kalmar
# Processing Record 27 of Set 5 | guasca
# Processing Record 28 of Set 5 | rio gallegos
# Processing Record 29 of Set 5 | egvekinot
# Processing Record 30 of Set 5 | la asuncion
# Processing Record 31 of Set 5 | turkistan
# Processing Record 32 of Set 5 | minas
# Processing Record 33 of Set 5 | luanda
# Processing Record 34 of Set 5 | maddur
# Processing Record 35 of Set 5 | aromashevo
# Processing Record 36 of Set 5 | necochea
# Processing Record 37 of Set 5 | shira
# Processing Record 38 of Set 5 | oranjemund
# Processing Record 39 of Set 5 | kununurra
# Processing Record 40 of Set 5 | maragogi
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | locri
# Processing Record 43 of Set 5 | yuxia
# Processing Record 44 of Set 5 | dikson
# Processing Record 45 of Set 5 | victor harbor
# Processing Record 46 of Set 5 | waipawa
# Processing Record 47 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 48 of Set 5 | palora
# Processing Record 49 of Set 5 | college
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | constitucion
# Processing Record 2 of Set 6 | jamsa
# Processing Record 3 of Set 6 | yzeure
# Processing Record 4 of Set 6 | nhulunbuy
# Processing Record 5 of Set 6 | hithadhoo
# Processing Record 6 of Set 6 | klaksvik
# Processing Record 7 of Set 6 | mvuma
# Processing Record 8 of Set 6 | la roche-sur-yon
# Processing Record 9 of Set 6 | onega
# Processing Record 10 of Set 6 | port victoria
# Processing Record 11 of Set 6 | krasnorechenskiy
# Processing Record 12 of Set 6 | ulladulla
# Processing Record 13 of Set 6 | pilar
# Processing Record 14 of Set 6 | barrow
# Processing Record 15 of Set 6 | ostrovnoy
# Processing Record 16 of Set 6 | grand gaube
# Processing Record 17 of Set 6 | ossora
# Processing Record 18 of Set 6 | bandarbeyla
# Processing Record 19 of Set 6 | porbandar
# Processing Record 20 of Set 6 | kibakwe
# Processing Record 21 of Set 6 | tiznit
# Processing Record 22 of Set 6 | fairbanks
# Processing Record 23 of Set 6 | mocuba
# Processing Record 24 of Set 6 | bulgan
# Processing Record 25 of Set 6 | kudahuvadhoo
# Processing Record 26 of Set 6 | tiksi
# Processing Record 27 of Set 6 | touros
# Processing Record 28 of Set 6 | inirida
# Processing Record 29 of Set 6 | fortuna
# Processing Record 30 of Set 6 | paraguacu paulista
# Processing Record 31 of Set 6 | upernavik
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | torbay
# Processing Record 34 of Set 6 | souillac
# Processing Record 35 of Set 6 | pingdingshan
# Processing Record 36 of Set 6 | georgetown
# Processing Record 37 of Set 6 | maniitsoq
# Processing Record 38 of Set 6 | calabozo
# Processing Record 39 of Set 6 | hami
# Processing Record 40 of Set 6 | along
# Processing Record 41 of Set 6 | birin
# Processing Record 42 of Set 6 | akyab
# Processing Record 43 of Set 6 | brody
# Processing Record 44 of Set 6 | vostok
# Processing Record 45 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 6 | krk
# Processing Record 47 of Set 6 | saint-philippe
# Processing Record 48 of Set 6 | puerto narino
# Processing Record 49 of Set 6 | laguna
# Processing Record 50 of Set 6 | kropotkin
# Processing Record 1 of Set 7 | bengkulu
# Processing Record 2 of Set 7 | laje
# Processing Record 3 of Set 7 | nobres
# Processing Record 4 of Set 7 | tuatapere
# Processing Record 5 of Set 7 | avera
# Processing Record 6 of Set 7 | mandalgovi
# Processing Record 7 of Set 7 | kalanwali
# Processing Record 8 of Set 7 | kholmogory
# Processing Record 9 of Set 7 | guarapari
# Processing Record 10 of Set 7 | aksha
# Processing Record 11 of Set 7 | kavieng
# Processing Record 12 of Set 7 | longyearbyen
# Processing Record 13 of Set 7 | tura
# Processing Record 14 of Set 7 | luganville
# Processing Record 15 of Set 7 | gimli
# Processing Record 16 of Set 7 | berlevag
# Processing Record 17 of Set 7 | margate
# Processing Record 18 of Set 7 | yulara
# Processing Record 19 of Set 7 | san antonio
# Processing Record 20 of Set 7 | wanning
# Processing Record 21 of Set 7 | mahebourg
# Processing Record 22 of Set 7 | dunedin
# Processing Record 23 of Set 7 | mao
# Processing Record 24 of Set 7 | tartagal
# Processing Record 25 of Set 7 | shkurinskaya
# Processing Record 26 of Set 7 | sao filipe
# Processing Record 27 of Set 7 | narasannapeta
# Processing Record 28 of Set 7 | eureka
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | sinjah
# City not found. Skipping...
# Processing Record 31 of Set 7 | moyale
# Processing Record 32 of Set 7 | alofi
# Processing Record 33 of Set 7 | samarai
# Processing Record 34 of Set 7 | pangnirtung
# Processing Record 35 of Set 7 | namatanai
# Processing Record 36 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 7 | lagoa
# Processing Record 38 of Set 7 | aksu
# Processing Record 39 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 40 of Set 7 | pareora
# Processing Record 41 of Set 7 | naze
# Processing Record 42 of Set 7 | balgazyn
# Processing Record 43 of Set 7 | ballina
# Processing Record 44 of Set 7 | riviere-du-loup
# Processing Record 45 of Set 7 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 46 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 7 | mitsamiouli
# Processing Record 48 of Set 7 | beroroha
# Processing Record 49 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 1 of Set 8 | lebyazhye
# Processing Record 2 of Set 8 | portland
# Processing Record 3 of Set 8 | puerto madryn
# Processing Record 4 of Set 8 | norman wells
# Processing Record 5 of Set 8 | aklavik
# Processing Record 6 of Set 8 | guerrero negro
# Processing Record 7 of Set 8 | urazovka
# Processing Record 8 of Set 8 | keflavik
# Processing Record 9 of Set 8 | cockburn town
# Processing Record 10 of Set 8 | raga
# Processing Record 11 of Set 8 | kaihua
# Processing Record 12 of Set 8 | toropets
# Processing Record 13 of Set 8 | jiazi
# Processing Record 14 of Set 8 | wanaka
# Processing Record 15 of Set 8 | antonina
# Processing Record 16 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 8 | boulder city
# Processing Record 18 of Set 8 | evensk
# Processing Record 19 of Set 8 | aljezur
# Processing Record 20 of Set 8 | les cayes
# Processing Record 21 of Set 8 | tombouctou
# Processing Record 22 of Set 8 | mount isa
# Processing Record 23 of Set 8 | pemba
# Processing Record 24 of Set 8 | chingirlau
# Processing Record 25 of Set 8 | san lorenzo
# Processing Record 26 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 27 of Set 8 | nisia floresta
# Processing Record 28 of Set 8 | west bay
# Processing Record 29 of Set 8 | fukue
# Processing Record 30 of Set 8 | krabi
# Processing Record 31 of Set 8 | asbe teferi
# Processing Record 32 of Set 8 | nueva loja
# Processing Record 33 of Set 8 | mehamn
# Processing Record 34 of Set 8 | narok
# Processing Record 35 of Set 8 | carutapera
# Processing Record 36 of Set 8 | neiafu
# Processing Record 37 of Set 8 | tapalpa
# Processing Record 38 of Set 8 | bursol
# City not found. Skipping...
# Processing Record 39 of Set 8 | cherskiy
# Processing Record 40 of Set 8 | arlit
# Processing Record 41 of Set 8 | yerbogachen
# Processing Record 42 of Set 8 | ipojuca
# Processing Record 43 of Set 8 | cabo san lucas
# Processing Record 44 of Set 8 | sechura
# Processing Record 45 of Set 8 | clyde river
# Processing Record 46 of Set 8 | pinillos
# Processing Record 47 of Set 8 | monroe
# Processing Record 48 of Set 8 | lokosovo
# Processing Record 49 of Set 8 | kokopo
# Processing Record 50 of Set 8 | derzhavinsk
# Processing Record 1 of Set 9 | dafeng
# Processing Record 2 of Set 9 | kodiak
# Processing Record 3 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 4 of Set 9 | encrucijada
# Processing Record 5 of Set 9 | batticaloa
# Processing Record 6 of Set 9 | marugame
# Processing Record 7 of Set 9 | catumbela
# Processing Record 8 of Set 9 | namibe
# Processing Record 9 of Set 9 | atar
# Processing Record 10 of Set 9 | itarema
# Processing Record 11 of Set 9 | barguzin
# Processing Record 12 of Set 9 | oakdale
# Processing Record 13 of Set 9 | akalkot
# Processing Record 14 of Set 9 | ellensburg
# Processing Record 15 of Set 9 | kurchum
# Processing Record 16 of Set 9 | khorixas
# Processing Record 17 of Set 9 | faanui
# Processing Record 18 of Set 9 | chalmette
# Processing Record 19 of Set 9 | hassan
# Processing Record 20 of Set 9 | kibungo
# Processing Record 21 of Set 9 | iracoubo
# Processing Record 22 of Set 9 | chekhov
# Processing Record 23 of Set 9 | kearney
# Processing Record 24 of Set 9 | sioux lookout
# Processing Record 25 of Set 9 | saquena
# Processing Record 26 of Set 9 | abu jubayhah
# City not found. Skipping...
# Processing Record 27 of Set 9 | ponta delgada
# Processing Record 28 of Set 9 | clarence town
# Processing Record 29 of Set 9 | ishim
# Processing Record 30 of Set 9 | cidreira
# Processing Record 31 of Set 9 | elk grove
# Processing Record 32 of Set 9 | nome
# Processing Record 33 of Set 9 | vaitape
# Processing Record 34 of Set 9 | olafsvik
# Processing Record 35 of Set 9 | alcantarilla
# Processing Record 36 of Set 9 | angelholm
# City not found. Skipping...
# Processing Record 37 of Set 9 | umm lajj
# Processing Record 38 of Set 9 | bathsheba
# Processing Record 39 of Set 9 | mabaruma
# Processing Record 40 of Set 9 | beloha
# Processing Record 41 of Set 9 | coihaique
# Processing Record 42 of Set 9 | monrovia
# Processing Record 43 of Set 9 | san andres
# Processing Record 44 of Set 9 | nazret
# Processing Record 45 of Set 9 | viedma
# Processing Record 46 of Set 9 | katha
# City not found. Skipping...
# Processing Record 47 of Set 9 | saint-augustin
# City not found. Skipping...
# Processing Record 48 of Set 9 | rio grande city
# Processing Record 49 of Set 9 | calvinia
# Processing Record 50 of Set 9 | mahibadhoo
# Processing Record 1 of Set 10 | virden
# Processing Record 2 of Set 10 | bonaventure
# Processing Record 3 of Set 10 | karratha
# Processing Record 4 of Set 10 | urengoy
# Processing Record 5 of Set 10 | rawson
# Processing Record 6 of Set 10 | arkhara
# Processing Record 7 of Set 10 | dzerzhinskoye
# Processing Record 8 of Set 10 | chahuites
# Processing Record 9 of Set 10 | chilca
# Processing Record 10 of Set 10 | twin falls
# Processing Record 11 of Set 10 | tongchuan
# Processing Record 12 of Set 10 | temaraia
# City not found. Skipping...
# Processing Record 13 of Set 10 | adolfo lopez mateos
# Processing Record 14 of Set 10 | ambulu
# Processing Record 15 of Set 10 | chute-aux-outardes
# Processing Record 16 of Set 10 | price
# Processing Record 17 of Set 10 | strezhevoy
# Processing Record 18 of Set 10 | leningradskiy
# Processing Record 19 of Set 10 | pangkalanbuun
# Processing Record 20 of Set 10 | buala
# Processing Record 21 of Set 10 | paka
# Processing Record 22 of Set 10 | bubaque
# Processing Record 23 of Set 10 | novo aripuana
# Processing Record 24 of Set 10 | lebork
# Processing Record 25 of Set 10 | bonavista
# Processing Record 26 of Set 10 | esperance
# Processing Record 27 of Set 10 | chai badan
# Processing Record 28 of Set 10 | ahipara
# Processing Record 29 of Set 10 | baghdad
# Processing Record 30 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 31 of Set 10 | torbat-e jam
# Processing Record 32 of Set 10 | cobija
# Processing Record 33 of Set 10 | becerril
# Processing Record 34 of Set 10 | san jose
# Processing Record 35 of Set 10 | tres arroyos
# Processing Record 36 of Set 10 | nemuro
# Processing Record 37 of Set 10 | ermelo
# Processing Record 38 of Set 10 | herat
# Processing Record 39 of Set 10 | liverpool
# Processing Record 40 of Set 10 | saint-francois
# Processing Record 41 of Set 10 | manaus
# Processing Record 42 of Set 10 | oranjestad
# Processing Record 43 of Set 10 | eyl
# Processing Record 44 of Set 10 | north bend
# Processing Record 45 of Set 10 | palm coast
# Processing Record 46 of Set 10 | teya
# Processing Record 47 of Set 10 | madison
# Processing Record 48 of Set 10 | the valley
# Processing Record 49 of Set 10 | thiruvananthapuram
# Processing Record 50 of Set 10 | ust-nera
# Processing Record 1 of Set 11 | kushmurun
# Processing Record 2 of Set 11 | jales
# Processing Record 3 of Set 11 | say
# Processing Record 4 of Set 11 | shu
# Processing Record 5 of Set 11 | poum
# Processing Record 6 of Set 11 | ketchikan
# Processing Record 7 of Set 11 | zavetnoye
# Processing Record 8 of Set 11 | faya
# Processing Record 9 of Set 11 | kaabong
# Processing Record 10 of Set 11 | polyarnyye zori
# Processing Record 11 of Set 11 | peterhead
# Processing Record 12 of Set 11 | katsuura
# Processing Record 13 of Set 11 | mandera
# Processing Record 14 of Set 11 | rabat
# Processing Record 15 of Set 11 | miandrivazo
# Processing Record 16 of Set 11 | iwanai
# Processing Record 17 of Set 11 | maine-soroa
# Processing Record 18 of Set 11 | aden
# Processing Record 19 of Set 11 | shush
# Processing Record 20 of Set 11 | zhigalovo
# Processing Record 21 of Set 11 | sorland
# Processing Record 22 of Set 11 | katherine
# Processing Record 23 of Set 11 | kasongo-lunda
# Processing Record 24 of Set 11 | kosa
# Processing Record 25 of Set 11 | manicore
# Processing Record 26 of Set 11 | kidal
# Processing Record 27 of Set 11 | kyren
# Processing Record 28 of Set 11 | panjab
# Processing Record 29 of Set 11 | antalya
# Processing Record 30 of Set 11 | kovdor
# Processing Record 31 of Set 11 | providencia
# Processing Record 32 of Set 11 | la ronge
# Processing Record 33 of Set 11 | ginda
# Processing Record 34 of Set 11 | puerto baquerizo moreno
# Processing Record 35 of Set 11 | mantamados
# Processing Record 36 of Set 11 | benguela
# Processing Record 37 of Set 11 | kattivakkam
# Processing Record 38 of Set 11 | flinders
# Processing Record 39 of Set 11 | saint anthony
# Processing Record 40 of Set 11 | pacific grove
# Processing Record 41 of Set 11 | pachino
# Processing Record 42 of Set 11 | biryusinsk
# Processing Record 43 of Set 11 | pisco
# Processing Record 44 of Set 11 | puerto ayacucho
# Processing Record 45 of Set 11 | izhma
# Processing Record 46 of Set 11 | ambilobe
# Processing Record 47 of Set 11 | bardiyah
# Processing Record 48 of Set 11 | roald
# Processing Record 49 of Set 11 | pitimbu
# Processing Record 50 of Set 11 | hornepayne
# Processing Record 1 of Set 12 | jacareacanga
# Processing Record 2 of Set 12 | lopsmarka
# Processing Record 3 of Set 12 | karpogory
# Processing Record 4 of Set 12 | cuauhtemoc
# Processing Record 5 of Set 12 | gatesville
# Processing Record 6 of Set 12 | alacaygan
# Processing Record 7 of Set 12 | arkhangelskoye
# Processing Record 8 of Set 12 | williston
# Processing Record 9 of Set 12 | tokur
# Processing Record 10 of Set 12 | zholymbet
# Processing Record 11 of Set 12 | hassleholm
# Processing Record 12 of Set 12 | pokhara
# Processing Record 13 of Set 12 | asau
# Processing Record 14 of Set 12 | yashkul
# Processing Record 15 of Set 12 | kirakira
# Processing Record 16 of Set 12 | kudat
# Processing Record 17 of Set 12 | lisakovsk
# Processing Record 18 of Set 12 | aleksandrovskoye
# Processing Record 19 of Set 12 | chifeng
# Processing Record 20 of Set 12 | khandyga
# Processing Record 21 of Set 12 | caravelas
# Processing Record 22 of Set 12 | ust-tsilma
# Processing Record 23 of Set 12 | mokolo
# Processing Record 24 of Set 12 | anloga
# Processing Record 25 of Set 12 | lashio
# Processing Record 26 of Set 12 | morant bay
# Processing Record 27 of Set 12 | puerto leguizamo
# Processing Record 28 of Set 12 | cambuci
# Processing Record 29 of Set 12 | prokuplje
# Processing Record 30 of Set 12 | bairiki
# Processing Record 31 of Set 12 | sao joao da barra
# Processing Record 32 of Set 12 | dudinka
# Processing Record 33 of Set 12 | dandong
# Processing Record 34 of Set 12 | forrest city
# Processing Record 35 of Set 12 | bilibino
# Processing Record 36 of Set 12 | villa rica
# Processing Record 37 of Set 12 | meilu
# City not found. Skipping...
# Processing Record 38 of Set 12 | vila
# Processing Record 39 of Set 12 | ucluelet
# Processing Record 40 of Set 12 | ongandjera
# Processing Record 41 of Set 12 | isangel
# Processing Record 42 of Set 12 | jammalamadugu
# Processing Record 43 of Set 12 | yakeshi
# Processing Record 44 of Set 12 | narva-joesuu
# Processing Record 45 of Set 12 | benjamin constant
# Processing Record 46 of Set 12 | songjianghe
# Processing Record 47 of Set 12 | kirove
# Processing Record 48 of Set 12 | westport
# Processing Record 49 of Set 12 | havre-saint-pierre
# Processing Record 50 of Set 12 | mandan
# Processing Record 1 of Set 13 | indergarh
# Processing Record 2 of Set 13 | tual
# Processing Record 3 of Set 13 | ejura
# Processing Record 4 of Set 13 | betioky
# Processing Record 5 of Set 13 | amberley
# Processing Record 6 of Set 13 | ciras
# City not found. Skipping...
# Processing Record 7 of Set 13 | moerai
# Processing Record 8 of Set 13 | yambio
# Processing Record 9 of Set 13 | conceicao do araguaia
# Processing Record 10 of Set 13 | cam pha
# City not found. Skipping...
# Processing Record 11 of Set 13 | hokitika
# Processing Record 12 of Set 13 | batagay-alyta
# Processing Record 13 of Set 13 | brae
# Processing Record 14 of Set 13 | pine bluff
# Processing Record 15 of Set 13 | gilgit
# Processing Record 16 of Set 13 | port keats
# Processing Record 17 of Set 13 | majene
# Processing Record 18 of Set 13 | werda
# Processing Record 19 of Set 13 | mercedes
# Processing Record 20 of Set 13 | houlton
# Processing Record 21 of Set 13 | high level
# Processing Record 22 of Set 13 | swift current
# Processing Record 23 of Set 13 | riohacha
# Processing Record 24 of Set 13 | peace river
# Processing Record 25 of Set 13 | neepawa
# Processing Record 26 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 27 of Set 13 | storm lake
# Processing Record 28 of Set 13 | tenenkou
# Processing Record 29 of Set 13 | camocim
# Processing Record 30 of Set 13 | acajutla
# Processing Record 31 of Set 13 | high prairie
# Processing Record 32 of Set 13 | komsomolskiy
# Processing Record 33 of Set 13 | muroto
# Processing Record 34 of Set 13 | naron
# Processing Record 35 of Set 13 | uruzgan
# Processing Record 36 of Set 13 | noumea
# Processing Record 37 of Set 13 | kyra
# Processing Record 38 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 39 of Set 13 | nishihara
# Processing Record 40 of Set 13 | mount gambier
# Processing Record 41 of Set 13 | miura
# Processing Record 42 of Set 13 | biltine
# Processing Record 43 of Set 13 | sehithwa
# Processing Record 44 of Set 13 | kurilsk
# Processing Record 45 of Set 13 | nicoya
# Processing Record 46 of Set 13 | nagorsk
# Processing Record 47 of Set 13 | kalyazin
# Processing Record 48 of Set 13 | mauganj
# Processing Record 49 of Set 13 | mujiayingzi
# Processing Record 50 of Set 13 | tupik
# Processing Record 1 of Set 14 | sola
# Processing Record 2 of Set 14 | sao felix do xingu
# Processing Record 3 of Set 14 | dakar
# Processing Record 4 of Set 14 | yumen
# Processing Record 5 of Set 14 | gigmoto
# Processing Record 6 of Set 14 | eseka
# Processing Record 7 of Set 14 | port lincoln
# Processing Record 8 of Set 14 | sosnovo-ozerskoye
# Processing Record 9 of Set 14 | piuma
# Processing Record 10 of Set 14 | garissa
# Processing Record 11 of Set 14 | riberalta
# Processing Record 12 of Set 14 | oleksandrivka
# Processing Record 13 of Set 14 | roma
# Processing Record 14 of Set 14 | brumadinho
# Processing Record 15 of Set 14 | junction city
# Processing Record 16 of Set 14 | tadine
# Processing Record 17 of Set 14 | tevaitoa
# Processing Record 18 of Set 14 | palauig
# Processing Record 19 of Set 14 | kirksville
# Processing Record 20 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 14 | delijan
# Processing Record 22 of Set 14 | palencia
# Processing Record 23 of Set 14 | andenes
# Processing Record 24 of Set 14 | kysyl-syr
# Processing Record 25 of Set 14 | iranshahr
# Processing Record 26 of Set 14 | ilulissat
# Processing Record 27 of Set 14 | duku
# Processing Record 28 of Set 14 | belokurikha
# Processing Record 29 of Set 14 | camacha
# Processing Record 30 of Set 14 | broome
# Processing Record 31 of Set 14 | cabreuva
# Processing Record 32 of Set 14 | otradnoye
# Processing Record 33 of Set 14 | gouyave
# Processing Record 34 of Set 14 | yarim
# Processing Record 35 of Set 14 | la romana
# Processing Record 36 of Set 14 | kwekwe
# Processing Record 37 of Set 14 | asmara
# Processing Record 38 of Set 14 | karakol
# Processing Record 39 of Set 14 | rocha
# Processing Record 40 of Set 14 | shwebo
# Processing Record 41 of Set 14 | ribeira brava
# Processing Record 42 of Set 14 | boa vista
# Processing Record 43 of Set 14 | sept-iles
# Processing Record 44 of Set 14 | mirandopolis
# Processing Record 45 of Set 14 | north platte
# Processing Record 46 of Set 14 | aneby
# Processing Record 47 of Set 14 | acambay
# Processing Record 48 of Set 14 | asino
# Processing Record 49 of Set 14 | rongcheng
# Processing Record 50 of Set 14 | kavaratti
# Processing Record 1 of Set 15 | port-cartier
# Processing Record 2 of Set 15 | breytovo
# Processing Record 3 of Set 15 | burnie
# Processing Record 4 of Set 15 | tongzi
# Processing Record 5 of Set 15 | strathpeffer
# Processing Record 6 of Set 15 | porto empedocle
# Processing Record 7 of Set 15 | grajau
# Processing Record 8 of Set 15 | walvis bay
# Processing Record 9 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 10 of Set 15 | riyadh
# Processing Record 11 of Set 15 | mayor pablo lagerenza
# Processing Record 12 of Set 15 | huarmey
# Processing Record 13 of Set 15 | turbat
# Processing Record 14 of Set 15 | gazojak
# Processing Record 15 of Set 15 | llanes
# Processing Record 16 of Set 15 | trojes
# Processing Record 17 of Set 15 | kaita
# Processing Record 18 of Set 15 | cartagena
# Processing Record 19 of Set 15 | chistoye
# Processing Record 20 of Set 15 | arys
# Processing Record 21 of Set 15 | nanuque
# Processing Record 22 of Set 15 | okha
# Processing Record 23 of Set 15 | baculin
# Processing Record 24 of Set 15 | cervo
# Processing Record 25 of Set 15 | ust-maya
# Processing Record 26 of Set 15 | rosetown
# Processing Record 27 of Set 15 | madang
# Processing Record 28 of Set 15 | krasnogvardeyskiy
# Processing Record 29 of Set 15 | lezajsk
# Processing Record 30 of Set 15 | agadez
# Processing Record 31 of Set 15 | korla
# Processing Record 32 of Set 15 | amazar
# Processing Record 33 of Set 15 | bowen
# Processing Record 34 of Set 15 | christchurch
# Processing Record 35 of Set 15 | keti bandar
# Processing Record 36 of Set 15 | sicamous
# Processing Record 37 of Set 15 | daru
# Processing Record 38 of Set 15 | primorsk
# Processing Record 39 of Set 15 | chaihe
# Processing Record 40 of Set 15 | mayumba
# Processing Record 41 of Set 15 | imeni poliny osipenko
# Processing Record 42 of Set 15 | redmond
# Processing Record 43 of Set 15 | lazaro cardenas
# Processing Record 44 of Set 15 | malangali
# Processing Record 45 of Set 15 | carauari
# Processing Record 46 of Set 15 | miri
# Processing Record 47 of Set 15 | hualmay
# Processing Record 48 of Set 15 | ponnani
# Processing Record 49 of Set 15 | preston
# Processing Record 50 of Set 15 | turtas
# Processing Record 1 of Set 16 | vanavara
# Processing Record 2 of Set 16 | gemena
# Processing Record 3 of Set 16 | tefe
# Processing Record 4 of Set 16 | broken hill
# Processing Record 5 of Set 16 | tarnogskiy gorodok
# Processing Record 6 of Set 16 | kargasok
# Processing Record 7 of Set 16 | beidao
# Processing Record 8 of Set 16 | puerto quijarro
# Processing Record 9 of Set 16 | marawi
# Processing Record 10 of Set 16 | san rafael
# Processing Record 11 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 12 of Set 16 | banavar
# Processing Record 13 of Set 16 | alice springs
# Processing Record 14 of Set 16 | ukiah
# Processing Record 15 of Set 16 | nadym

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0     angouleme  45.6500    0.1500     38.35           clear sky        91
# 1          mayo  38.8876  -76.5119     31.86           clear sky        71
# 2    bredasdorp -34.5322   20.0403     72.28          few clouds        98
# 3     carnarvon -24.8667  113.6333     86.07           clear sky        58
# 4     ostersund  63.1792   14.6357     10.62     overcast clouds        92
# 5   tuktoyaktuk  69.4541 -133.0374    -18.40    scattered clouds        69
# 6  punta arenas -53.1500  -70.9167     46.51       broken clouds        76
# 7          guye  39.7333  118.4167     24.03           clear sky        32
# 8        maceio  -9.6658  -35.7353     78.24           clear sky        88
# 9    chokurdakh  70.6333  147.9167    -12.42     overcast clouds        93
#
#    Cloudiness  Wind Speed Country
# 0           0        5.75      FR
# 1           0        0.00      US
# 2          21        5.48      ZA
# 3           4       16.11      AU
# 4         100        8.05      SE
# 5          40        2.30      CA
# 6          75       14.97      CL
# 7           0        4.94      CN
# 8           0        4.61      BR
# 9         100        1.39      RU

# %%
# Create the output file (CSV).
output_data_file = "../Module 6/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
print(city_data)
# Out:
# [{'City': 'angouleme', 'Lat': 45.65, 'Lng': 0.15, 'Max Temp': 38.35, 'Current Description': 'clear sky', 'Humidity': 91, 'Cloudiness': 0, 'Wind Speed': 5.75, 'Country': 'FR'}, {'City': 'mayo', 'Lat': 38.8876, 'Lng': -76.5119, 'Max Temp': 31.86, 'Current Description': 'clear sky', 'Humidity': 71, 'Cloudiness': 0, 'Wind Speed': 0, 'Country': 'US'}, {'City': 'bredasdorp', 'Lat': -34.5322, 'Lng': 20.0403, 'Max Temp': 72.28, 'Current Description': 'few clouds', 'Humidity': 98, 'Cloudiness': 21, 'Wind Speed': 5.48, 'Country': 'ZA'}, {'City': 'carnarvon', 'Lat': -24.8667, 'Lng': 113.6333, 'Max Temp': 86.07, 'Current Description': 'clear sky', 'Humidity': 58, 'Cloudiness': 4, 'Wind Speed': 16.11, 'Country': 'AU'}, {'City': 'ostersund', 'Lat': 63.1792, 'Lng': 14.6357, 'Max Temp': 10.62, 'Current Description': 'overcast clouds', 'Humidity': 92, 'Cloudiness': 100, 'Wind Speed': 8.05, 'Country': 'SE'}, {'City': 'tuktoyaktuk', 'Lat': 69.4541, 'Lng': -133.0374, 'Max Temp': -18.4, 'Current Description': 'scattered clouds', 'Humidity': 69, 'Cloudiness': 40, 'Wind Speed': 2.3, 'Country': 'CA'}, {'City': 'punta arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max Temp': 46.51, 'Current Description': 'broken clouds', 'Humidity': 76, 'Cloudiness': 75, 'Wind Speed': 14.97, 'Country': 'CL'}, {'City': 'guye', 'Lat': 39.7333, 'Lng': 118.4167, 'Max Temp': 24.03, 'Current Description': 'clear sky', 'Humidity': 32, 'Cloudiness': 0, 'Wind Speed': 4.94, 'Country': 'CN'}, {'City': 'maceio', 'Lat': -9.6658, 'Lng': -35.7353, 'Max Temp': 78.24, 'Current Description': 'clear sky', 'Humidity': 88, 'Cloudiness': 0, 'Wind Speed': 4.61, 'Country': 'BR'}, {'City': 'chokurdakh', 'Lat': 70.6333, 'Lng': 147.9167, 'Max Temp': -12.42, 'Current Description': 'overcast clouds', 'Humidity': 93, 'Cloudiness': 100, 'Wind Speed': 1.39, 'Country': 'RU'}, {'City': 'motygino', 'Lat': 58.1831, 'Lng': 94.7592, 'Max Temp': -9.63, 'Current Description': 'scattered clouds', 'Humidity': 99, 'Cloudiness': 43, 'Wind Speed': 2.53, 'Country': 'RU'}, {'City': 'mar del plata', 'Lat': -38.0023, 'Lng': -57.5575, 'Max Temp': 64.87, 'Current Description': 'clear sky', 'Humidity': 54, 'Cloudiness': 0, 'Wind Speed': 1.99, 'Country': 'AR'}, {'City': 'soyo', 'Lat': -6.1349, 'Lng': 12.3689, 'Max Temp': 78.03, 'Current Description': 'overcast clouds', 'Humidity': 87, 'Cloudiness': 100, 'Wind Speed': 6.06, 'Country': 'AO'}, {'City': 'provideniya', 'Lat': 64.3833, 'Lng': -173.3, 'Max Temp': 8.71, 'Current Description': 'broken clouds', 'Humidity': 66, 'Cloudiness': 75, 'Wind Speed': 15.66, 'Country': 'RU'}, {'City': 'balkhash', 'Lat': 46.844, 'Lng': 74.9804, 'Max Temp': 12.81, 'Current Description': 'broken clouds', 'Humidity': 85, 'Cloudiness': 75, 'Wind Speed': 15.66, 'Country': 'KZ'}, {'City': 'ushuaia', 'Lat': -54.8, 'Lng': -68.3, 'Max Temp': 40.66, 'Current Description': 'light intensity drizzle', 'Humidity': 87, 'Cloudiness': 75, 'Wind Speed': 17.27, 'Country': 'AR'}, {'City': 'kapaa', 'Lat': 22.0752, 'Lng': -159.319, 'Max Temp': 76.12, 'Current Description': 'light rain', 'Humidity': 59, 'Cloudiness': 100, 'Wind Speed': 1.99, 'Country': 'US'}, {'City': 'los llanos de aridane', 'Lat': 28.6585, 'Lng': -17.9182, 'Max Temp': 56.95, 'Current Description': 'clear sky', 'Humidity': 58, 'Cloudiness': 0, 'Wind Speed': 5.99, 'Country': 'ES'}, {'City': 'kruisfontein', 'Lat': -34.0033, 'Lng': 24.7314, 'Max Temp': 70.88, 'Current Description': 'overcast clouds', 'Humidity': 96, 'Cloudiness': 98, 'Wind Speed': 3.8, 'Country': 'ZA'}, {'City': 'beringovskiy', 'Lat': 63.05, 'Lng': 179.3167, 'Max Temp': 10.31, 'Current Description': 'snow', 'Humidity': 94, 'Cloudiness': 100, 'Wind Speed': 19.71, 'Country': 'RU'}, {'City': 'hilo', 'Lat': 19.7297, 'Lng': -155.09, 'Max Temp': 78.53, 'Current Description': 'scattered clouds', 'Humidity': 69, 'Cloudiness': 40, 'Wind Speed': 11.5, 'Country': 'US'}, {'City': 'mataura', 'Lat': -46.1927, 'Lng': 168.8643, 'Max Temp': 72.48, 'Current Description': 'overcast clouds', 'Humidity': 46 ...

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#             City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0      angouleme  45.6500    0.1500     38.35           clear sky        91
# 1           mayo  38.8876  -76.5119     31.86           clear sky        71
# 4      ostersund  63.1792   14.6357     10.62     overcast clouds        92
# 5    tuktoyaktuk  69.4541 -133.0374    -18.40    scattered clouds        69
# 7           guye  39.7333  118.4167     24.03           clear sky        32
# ..           ...      ...       ...       ...                 ...       ...
# 709       beidao  34.5686  105.8933     21.65     overcast clouds        83
# 711       marawi   7.9986  124.2928     77.61       broken clouds        67
# 713      banavar  13.4136   76.1683     66.94          few clouds        57
# 715        ukiah  39.1502 -123.2078     56.01           clear sky        57
# 716        nadym  65.5333   72.5167    -17.14     overcast clouds       100
#
#      Cloudiness  Wind Speed Country
# 0             0        5.75      FR
# 1             0        0.00      US
# 4           100        8.05      SE
# 5            40        2.30      CA
# 7             0        4.94      CN
# ..          ...         ...     ...
# 709         100        1.32      CN
# 711          55        3.89      PH
# 713          24        3.31      IN
# 715           0        8.05      US
# 716         100        6.87      RU
#
# [500 rows x 9 columns]
